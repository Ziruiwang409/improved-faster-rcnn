# %%
import numpy as np
from utils.dataset import Kitti
import torch
from torch.utils.data import DataLoader
from torchvision.transforms import ToTensor
import importlib

# %% [markdown]
# #### Kitti Dataloader

# %%
from utils import dataset
importlib.reload(dataset)
training_data = dataset.Kitti(train=True,transforms=None)
print('Total number of training image: ', len(training_data))
# Out:
# Total number of training image:  7481

# %% [markdown]
# ##### Sample image

# %%
import matplotlib.pyplot as plt
img, label = training_data[256]
plt.title("training image [256]")
plt.imshow(img)
print("Type: ", label[0]['type'])
# Out:
# Type:  Car
